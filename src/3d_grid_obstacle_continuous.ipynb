# %% [markdown]
# # Navigating a 3D grid with an obstacle by reinforcement learning (continous action space)
#
# ## Salient features:
# 1) Custom Gym environment
# 2) Training a reinforcement learning agent using Stable-baselines
#
# ## Important links
# Stable-Baselines: https://github.com/hill-a/stable-baselines
#
# Documentation: https://stable-baselines.readthedocs.io/en/master/
#
# RL Baselines zoo: https://github.com/araffin/rl-baselines-zoo

# %%
from stable_baselines3.common.env_checker import check_env
import gym
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import A2C, DDPG, SAC
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ## The gym interface
#
# The gym interface provides mainly three methods:
# - `reset()` called at the beginning of an episode, it returns an observation
# - `step(action)` called to take an action with the environment, it returns the next observation, the immediate reward, whether the episode is over and additional information
# - (Optional) `render(method='human')` which allow to visualize the agent in action. Note that graphical interface does not work on google colab, so we cannot use it directly (we have to rely on `method='rbg_array'` to retrieve an image of the scene
#
# Under the hood, it also contains two useful properties:
# - `observation_space` which one of the gym spaces (`Discrete`, `Box`, ...) and describe the type and shape of the observation
# - `action_space` which is also a gym space object that describes the action space, so the type of action that can be taken
#
# [Documentation on custom env](https://stable-baselines.readthedocs.io/en/master/guide/custom_env.html)

# %% [markdown]
# ##  Gym environment

# %%
class ReachEndEnv(gym.Env):
    """
    This is a simple env where the agent must learn to reach the destination with obstacles in between. 
    """
    metadata = {'render.modes': ['console']}

    def __init__(self, grid_size=4,block_low=1,block_high=2):
        super(ReachEndEnv, self).__init__()

        # Size of the 3D-grid
        self.grid_size = grid_size
        # Initialize the agent at the top left corner
        self.initial_pos = np.zeros((3,),dtype=np.float32) 
        self.agent_pos = np.zeros((3,),dtype=np.float32)
        # Specify the blocked region
        self.block_low =block_low
        self.block_high =block_high
        self.act_low = -1.0
        self.act_high = 1.0
        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions, we have two: left and right
        self.action_space = spaces.Box(low=self.act_low, high=self.act_high, shape=(3,), dtype=np.float32)
        # The observation will be the coordinate of the agent
        # this can be described both by Discrete and Box space
        self.observation_space = spaces.Box(low=0, high=self.grid_size, shape=(3,), dtype=np.float32)
        # Check if goal is reached
        self.endcheck = False

    def reset(self):
        """
        Important: the observation must be a numpy array
        :return: (np.array) 
        """
        # Initialize the agent at the right of the grid
        self.agent_pos = np.zeros((3,),dtype=np.float32)#self.initial_pos
        # here we convert to float32 to make it more general (in case we want to use continuous actions)
        # return np.array([self.agent_pos]).astype(np.float32)
        return self.agent_pos

    def step(self, action):

            
        self.agent_pos += action
        if action[0]<self.act_low or action[0]>self.act_high:
            raise ValueError("Received invalid action={} which is not part of the action space".format(action))
        if action[1]<self.act_low or action[1]>self.act_high:
            raise ValueError("Received invalid action={} which is not part of the action space".format(action)) 
        if action[2]<self.act_low or action[2]>self.act_high:
            raise ValueError("Received invalid action={} which is not part of the action space".format(action))    

        # Account for the boundaries of the grid
        self.agent_pos = np.clip(self.agent_pos, 0, self.grid_size-1)

        # Are we at the end?
        done = bool(self.agent_pos[0] == self.grid_size-1 and self.agent_pos[1]==self.grid_size-1 and \
                    self.agent_pos[2]==self.grid_size-1)

        # Null reward everywhere except when reaching the goal (right corner)
        if self.agent_pos[0] == self.grid_size-1 and self.agent_pos[1]==self.grid_size-1 and \
        self.agent_pos[2]==self.grid_size-1: 
            reward = 1
        elif self.agent_pos[0]>=self.block_low and self.agent_pos[0]<=self.block_high and \
        self.agent_pos[1]>=self.block_low and self.agent_pos[1]<=self.block_high and\
        self.agent_pos[2]>=self.block_low and self.agent_pos[2]<=self.block_high:
            reward = -10
        else:
            reward = -1

        # Optionally we can pass additional info, we are not using that for now
        info = {}
        self.endcheck = done

        return self.agent_pos, reward, done, info

    def render(self, mode='console'):
        if mode != 'console':
            raise NotImplementedError()        

    def close(self):
        pass

# %% [markdown]
# ### Validate the environment
#
# Stable Baselines provides a [helper](https://stable-baselines.readthedocs.io/en/master/common/env_checker.html) to check that your environment follows the Gym interface. It also optionally checks that the environment is compatible with Stable-Baselines (and emits warning if necessary).

# %%
env = ReachEndEnv()
# If the environment don't follow the interface, an error will be thrown
check_env(env, warn=True)

# %%
# Instantiate the env
env = ReachEndEnv(grid_size=10,block_low=3,block_high=6)
# wrap it
env = make_vec_env(lambda: env, n_envs=1)

# %%
# Train the agent
# Using Deep Deterministic Policy gradient
model = DDPG('MlpPolicy', env, train_freq= 4, tensorboard_log='./log_files/',verbose=1).learn(500000)
# Out:
# Using cuda device
# Logging to ./log_files/DDPG_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 8.45e+04  |
# |    ep_rew_mean     | -8.46e+04 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 183       |
# |    time_elapsed    | 1839      |
# |    total_timesteps | 338001    |
# | train/             |           |
# |    actor_loss      | 95.2      |
# |    critic_loss     | 0.0459    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 337900    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.23e+04  |
# |    ep_rew_mean     | -4.23e+04 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 183       |
# |    time_elapsed    | 1839      |
# |    total_timesteps | 338055    |
# | train/             |           |
# |    actor_loss      | 95.1      |
# |    critic_loss     | 0.188     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 337952    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.82e+04  |
# |    ep_rew_mean     | -2.82e+04 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 183       |
# |    time_elapsed    | 1839      |
# |    total_timesteps | 338115    |
# | train/             |           |
# |    actor_loss      | 95.1      |
# |    critic_loss     | 0.00746   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338012    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.11e+04  |
# |    ep_rew_mean     | -2.11e+04 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 183       |
# |    time_elapsed    | 1839      |
# |    total_timesteps | 338175    |
# | train/             |           |
# |    actor_loss      | 95.1      |
# |    critic_loss     | 0.145     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338072    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.69e+04  |
# |    ep_rew_mean     | -1.69e+04 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 183       |
# |    time_elapsed    | 1843      |
# |    total_timesteps | 338697    |
# | train/             |           |
# |    actor_loss      | 94.9      |
# |    critic_loss     | 0.00329   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338596    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.41e+04  |
# |    ep_rew_mean     | -1.41e+04 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 183       |
# |    time_elapsed    | 1843      |
# |    total_timesteps | 338826    |
# | train/             |           |
# |    actor_loss      | 94.8      |
# |    critic_loss     | 0.00572   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338724    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.21e+04  |
# |    ep_rew_mean     | -1.21e+04 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 183       |
# |    time_elapsed    | 1844      |
# |    total_timesteps | 338886    |
# | train/             |           |
# |    actor_loss      | 94.8      |
# |    critic_loss     | 0.005     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338784    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.06e+04  |
# |    ep_rew_mean     | -1.06e+04 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 183       |
# |    time_elapsed    | 1844      |
# |    total_timesteps | 338944    |
# | train/             |           |
# |    actor_loss      | 94.7      |
# |    critic_loss     | 0.00382   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338840    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 9.42e+03  |
# |    ep_rew_mean     | -9.42e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 183       |
# |    time_elapsed    | 1844      |
# |    total_timesteps | 338999    |
# | train/             |           |
# |    actor_loss      | 94.3      |
# |    critic_loss     | 0.184     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338896    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 8.48e+03  |
# |    ep_rew_mean     | -8.48e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 183       |
# |    time_elapsed    | 1845      |
# |    total_timesteps | 339048    |
# | train/             |           |
# |    actor_loss      | 94.7      |
# |    critic_loss     | 0.0098    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 338944    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 7.71e+03  |
# |    ep_rew_mean     | -7.71e+03 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 183       |
# |    time_elapsed    | 1845      |
# |    total_timesteps | 339101    |
# | train/             |           |
# |    actor_loss      | 94.5      |
# |    critic_loss     | 0.0193    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339000    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 7.07e+03  |
# |    ep_rew_mean     | -7.07e+03 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 183       |
# |    time_elapsed    | 1845      |
# |    total_timesteps | 339153    |
# | train/             |           |
# |    actor_loss      | 94.6      |
# |    critic_loss     | 0.0256    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339052    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.52e+03  |
# |    ep_rew_mean     | -6.53e+03 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 183       |
# |    time_elapsed    | 1846      |
# |    total_timesteps | 339205    |
# | train/             |           |
# |    actor_loss      | 94.2      |
# |    critic_loss     | 0.101     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339104    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 6.06e+03  |
# |    ep_rew_mean     | -6.06e+03 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 183       |
# |    time_elapsed    | 1846      |
# |    total_timesteps | 339258    |
# | train/             |           |
# |    actor_loss      | 93.9      |
# |    critic_loss     | 0.593     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339156    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.66e+03  |
# |    ep_rew_mean     | -5.66e+03 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 183       |
# |    time_elapsed    | 1846      |
# |    total_timesteps | 339311    |
# | train/             |           |
# |    actor_loss      | 93.7      |
# |    critic_loss     | 1.07      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339208    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 5.3e+03   |
# |    ep_rew_mean     | -5.31e+03 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 183       |
# |    time_elapsed    | 1846      |
# |    total_timesteps | 339363    |
# | train/             |           |
# |    actor_loss      | 93.1      |
# |    critic_loss     | 19.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339260    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.99e+03  |
# |    ep_rew_mean     | -4.99e+03 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 183       |
# |    time_elapsed    | 1847      |
# |    total_timesteps | 339415    |
# | train/             |           |
# |    actor_loss      | 94.5      |
# |    critic_loss     | 0.547     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339312    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.71e+03  |
# |    ep_rew_mean     | -4.72e+03 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 183       |
# |    time_elapsed    | 1847      |
# |    total_timesteps | 339467    |
# | train/             |           |
# |    actor_loss      | 93.7      |
# |    critic_loss     | 0.0482    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339364    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.47e+03  |
# |    ep_rew_mean     | -4.47e+03 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 183       |
# |    time_elapsed    | 1847      |
# |    total_timesteps | 339519    |
# | train/             |           |
# |    actor_loss      | 93.3      |
# |    critic_loss     | 0.082     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339416    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.24e+03  |
# |    ep_rew_mean     | -4.25e+03 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 183       |
# |    time_elapsed    | 1848      |
# |    total_timesteps | 339571    |
# | train/             |           |
# |    actor_loss      | 93.1      |
# |    critic_loss     | 0.336     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339468    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 4.04e+03  |
# |    ep_rew_mean     | -4.04e+03 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 183       |
# |    time_elapsed    | 1848      |
# |    total_timesteps | 339623    |
# | train/             |           |
# |    actor_loss      | 92.9      |
# |    critic_loss     | 0.156     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339520    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.86e+03  |
# |    ep_rew_mean     | -3.86e+03 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 183       |
# |    time_elapsed    | 1848      |
# |    total_timesteps | 339675    |
# | train/             |           |
# |    actor_loss      | 92.4      |
# |    critic_loss     | 0.831     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339572    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.69e+03  |
# |    ep_rew_mean     | -3.69e+03 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 183       |
# |    time_elapsed    | 1849      |
# |    total_timesteps | 339727    |
# | train/             |           |
# |    actor_loss      | 92.7      |
# |    critic_loss     | 0.14      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339624    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 3.54e+03  |
# |    ep_rew_mean     | -3.54e+03 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 183       |
# |    time_elapsed    | 1849      |
# |    total_timesteps | 339777    |
# | train/             |           |
# |    actor_loss      | 91.8      |
# |    critic_loss     | 0.255     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 339676    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.4e+03  |
# |    ep_rew_mean     | -3.4e+03 |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 183      |
# |    time_elapsed    | 1849     |
# |    total_timesteps | 339825   |
# | train/             |          |
# |    actor_loss      | 91.2     |
# |    critic_loss     | 0.554    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339724   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.7     |
# |    ep_rew_mean     | -18.3    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 183      |
# |    time_elapsed    | 1850     |
# |    total_timesteps | 339873   |
# | train/             |          |
# |    actor_loss      | 91.9     |
# |    critic_loss     | 0.182    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339772   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.7     |
# |    ep_rew_mean     | -18.5    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 183      |
# |    time_elapsed    | 1850     |
# |    total_timesteps | 339923   |
# | train/             |          |
# |    actor_loss      | 90.6     |
# |    critic_loss     | 0.418    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339820   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.6     |
# |    ep_rew_mean     | -18.7    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 183      |
# |    time_elapsed    | 1850     |
# |    total_timesteps | 339971   |
# | train/             |          |
# |    actor_loss      | 90.6     |
# |    critic_loss     | 0.254    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339868   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.4     |
# |    ep_rew_mean     | -19      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 183      |
# |    time_elapsed    | 1850     |
# |    total_timesteps | 340019   |
# | train/             |          |
# |    actor_loss      | 90.3     |
# |    critic_loss     | 0.0521   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339916   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.7     |
# |    ep_rew_mean     | -14.4    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 183      |
# |    time_elapsed    | 1851     |
# |    total_timesteps | 340067   |
# | train/             |          |
# |    actor_loss      | 90.1     |
# |    critic_loss     | 0.0546   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 339964   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.9     |
# |    ep_rew_mean     | -13.9    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 183      |
# |    time_elapsed    | 1851     |
# |    total_timesteps | 340115   |
# | train/             |          |
# |    actor_loss      | 89.9     |
# |    critic_loss     | 0.318    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340012   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.8     |
# |    ep_rew_mean     | -14.2    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 183      |
# |    time_elapsed    | 1851     |
# |    total_timesteps | 340163   |
# | train/             |          |
# |    actor_loss      | 89       |
# |    critic_loss     | 0.535    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340060   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.7     |
# |    ep_rew_mean     | -14.4    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 183      |
# |    time_elapsed    | 1852     |
# |    total_timesteps | 340211   |
# | train/             |          |
# |    actor_loss      | 88.7     |
# |    critic_loss     | 0.332    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340108   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.6     |
# |    ep_rew_mean     | -14.7    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 183      |
# |    time_elapsed    | 1852     |
# |    total_timesteps | 340259   |
# | train/             |          |
# |    actor_loss      | 88.7     |
# |    critic_loss     | 0.053    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340156   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.6     |
# |    ep_rew_mean     | -14.7    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 183      |
# |    time_elapsed    | 1852     |
# |    total_timesteps | 340307   |
# | train/             |          |
# |    actor_loss      | 87.5     |
# |    critic_loss     | 1.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340204   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.5     |
# |    ep_rew_mean     | -14.9    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 183      |
# |    time_elapsed    | 1852     |
# |    total_timesteps | 340355   |
# | train/             |          |
# |    actor_loss      | 86       |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340252   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.5     |
# |    ep_rew_mean     | -15.2    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 183      |
# |    time_elapsed    | 1853     |
# |    total_timesteps | 340403   |
# | train/             |          |
# |    actor_loss      | 86.9     |
# |    critic_loss     | 0.345    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340300   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.5     |
# |    ep_rew_mean     | -15.5    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 183      |
# |    time_elapsed    | 1853     |
# |    total_timesteps | 340451   |
# | train/             |          |
# |    actor_loss      | 86.4     |
# |    critic_loss     | 0.0758   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340348   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.4     |
# |    ep_rew_mean     | -15.8    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 183      |
# |    time_elapsed    | 1853     |
# |    total_timesteps | 340499   |
# | train/             |          |
# |    actor_loss      | 85       |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340396   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.4     |
# |    ep_rew_mean     | -16.1    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 183      |
# |    time_elapsed    | 1854     |
# |    total_timesteps | 340547   |
# | train/             |          |
# |    actor_loss      | 85.5     |
# |    critic_loss     | 0.327    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340444   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.3     |
# |    ep_rew_mean     | -16.4    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 183      |
# |    time_elapsed    | 1854     |
# |    total_timesteps | 340595   |
# | train/             |          |
# |    actor_loss      | 84.8     |
# |    critic_loss     | 0.245    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340492   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.3     |
# |    ep_rew_mean     | -16.8    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 183      |
# |    time_elapsed    | 1854     |
# |    total_timesteps | 340643   |
# | train/             |          |
# |    actor_loss      | 83.5     |
# |    critic_loss     | 0.241    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340540   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.2     |
# |    ep_rew_mean     | -17.2    |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 183      |
# |    time_elapsed    | 1854     |
# |    total_timesteps | 340689   |
# | train/             |          |
# |    actor_loss      | 82.8     |
# |    critic_loss     | 0.423    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340588   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.2     |
# |    ep_rew_mean     | -17.6    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 183      |
# |    time_elapsed    | 1855     |
# |    total_timesteps | 340737   |
# | train/             |          |
# |    actor_loss      | 81.9     |
# |    critic_loss     | 0.344    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340636   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.1     |
# |    ep_rew_mean     | -17.9    |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 183      |
# |    time_elapsed    | 1855     |
# |    total_timesteps | 340785   |
# | train/             |          |
# |    actor_loss      | 81.8     |
# |    critic_loss     | 0.0826   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340684   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12.1     |
# |    ep_rew_mean     | -18.4    |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 183      |
# |    time_elapsed    | 1855     |
# |    total_timesteps | 340831   |
# | train/             |          |
# |    actor_loss      | 80.9     |
# |    critic_loss     | 0.235    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 12       |
# |    ep_rew_mean     | -19      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 183      |
# |    time_elapsed    | 1855     |
# |    total_timesteps | 340875   |
# | train/             |          |
# |    actor_loss      | 80.1     |
# |    critic_loss     | 0.0795   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340772   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.9     |
# |    ep_rew_mean     | -19.6    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 183      |
# |    time_elapsed    | 1856     |
# |    total_timesteps | 340919   |
# | train/             |          |
# |    actor_loss      | 80.2     |
# |    critic_loss     | 0.201    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.9     |
# |    ep_rew_mean     | -20.1    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 183      |
# |    time_elapsed    | 1856     |
# |    total_timesteps | 340963   |
# | train/             |          |
# |    actor_loss      | 78       |
# |    critic_loss     | 4.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340860   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.8     |
# |    ep_rew_mean     | -20.4    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 183      |
# |    time_elapsed    | 1856     |
# |    total_timesteps | 341007   |
# | train/             |          |
# |    actor_loss      | 77.8     |
# |    critic_loss     | 0.446    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.8     |
# |    ep_rew_mean     | -20.8    |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 183      |
# |    time_elapsed    | 1856     |
# |    total_timesteps | 341050   |
# | train/             |          |
# |    actor_loss      | 77.6     |
# |    critic_loss     | 0.205    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340948   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.7     |
# |    ep_rew_mean     | -21.6    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 183      |
# |    time_elapsed    | 1857     |
# |    total_timesteps | 341090   |
# | train/             |          |
# |    actor_loss      | 76.5     |
# |    critic_loss     | 3.78     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 340988   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.6     |
# |    ep_rew_mean     | -22.3    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 183      |
# |    time_elapsed    | 1857     |
# |    total_timesteps | 341130   |
# | train/             |          |
# |    actor_loss      | 75.2     |
# |    critic_loss     | 0.107    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341028   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.5     |
# |    ep_rew_mean     | -22.9    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 183      |
# |    time_elapsed    | 1857     |
# |    total_timesteps | 341170   |
# | train/             |          |
# |    actor_loss      | 74.7     |
# |    critic_loss     | 0.174    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341068   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.4     |
# |    ep_rew_mean     | -23.6    |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 183      |
# |    time_elapsed    | 1857     |
# |    total_timesteps | 341210   |
# | train/             |          |
# |    actor_loss      | 74.3     |
# |    critic_loss     | 0.106    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341108   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.3     |
# |    ep_rew_mean     | -24.2    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 183      |
# |    time_elapsed    | 1858     |
# |    total_timesteps | 341250   |
# | train/             |          |
# |    actor_loss      | 74.1     |
# |    critic_loss     | 0.118    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341148   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.3     |
# |    ep_rew_mean     | -24.8    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 183      |
# |    time_elapsed    | 1858     |
# |    total_timesteps | 341290   |
# | train/             |          |
# |    actor_loss      | 72.1     |
# |    critic_loss     | 2.64     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341188   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.2     |
# |    ep_rew_mean     | -25.5    |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 183      |
# |    time_elapsed    | 1858     |
# |    total_timesteps | 341330   |
# | train/             |          |
# |    actor_loss      | 72       |
# |    critic_loss     | 4.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341228   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.1     |
# |    ep_rew_mean     | -26.3    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 183      |
# |    time_elapsed    | 1858     |
# |    total_timesteps | 341370   |
# | train/             |          |
# |    actor_loss      | 71.2     |
# |    critic_loss     | 0.132    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341268   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11       |
# |    ep_rew_mean     | -27      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 183      |
# |    time_elapsed    | 1859     |
# |    total_timesteps | 341410   |
# | train/             |          |
# |    actor_loss      | 70.4     |
# |    critic_loss     | 0.163    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341308   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.9     |
# |    ep_rew_mean     | -27.7    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 183      |
# |    time_elapsed    | 1859     |
# |    total_timesteps | 341450   |
# | train/             |          |
# |    actor_loss      | 69.8     |
# |    critic_loss     | 0.14     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341348   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.9     |
# |    ep_rew_mean     | -28.3    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 183      |
# |    time_elapsed    | 1859     |
# |    total_timesteps | 341490   |
# | train/             |          |
# |    actor_loss      | 67.3     |
# |    critic_loss     | 0.406    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341388   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.8     |
# |    ep_rew_mean     | -28.9    |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 183      |
# |    time_elapsed    | 1859     |
# |    total_timesteps | 341530   |
# | train/             |          |
# |    actor_loss      | 67.7     |
# |    critic_loss     | 0.311    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341428   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.7     |
# |    ep_rew_mean     | -29.6    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 183      |
# |    time_elapsed    | 1860     |
# |    total_timesteps | 341570   |
# | train/             |          |
# |    actor_loss      | 66.8     |
# |    critic_loss     | 1.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341468   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.6     |
# |    ep_rew_mean     | -30.2    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 183      |
# |    time_elapsed    | 1860     |
# |    total_timesteps | 341610   |
# | train/             |          |
# |    actor_loss      | 66       |
# |    critic_loss     | 0.145    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341508   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.6     |
# |    ep_rew_mean     | -31.1    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 183      |
# |    time_elapsed    | 1860     |
# |    total_timesteps | 341650   |
# | train/             |          |
# |    actor_loss      | 65       |
# |    critic_loss     | 1.36     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341548   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.5     |
# |    ep_rew_mean     | -32      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 183      |
# |    time_elapsed    | 1860     |
# |    total_timesteps | 341690   |
# | train/             |          |
# |    actor_loss      | 64.5     |
# |    critic_loss     | 0.229    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341588   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.4     |
# |    ep_rew_mean     | -32.9    |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 183      |
# |    time_elapsed    | 1861     |
# |    total_timesteps | 341730   |
# | train/             |          |
# |    actor_loss      | 63.5     |
# |    critic_loss     | 0.581    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341628   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.3     |
# |    ep_rew_mean     | -33.9    |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 183      |
# |    time_elapsed    | 1861     |
# |    total_timesteps | 341770   |
# | train/             |          |
# |    actor_loss      | 62.5     |
# |    critic_loss     | 0.138    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341668   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.2     |
# |    ep_rew_mean     | -34.9    |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 183      |
# |    time_elapsed    | 1861     |
# |    total_timesteps | 341810   |
# | train/             |          |
# |    actor_loss      | 61.6     |
# |    critic_loss     | 0.475    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341708   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.2     |
# |    ep_rew_mean     | -35.7    |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 183      |
# |    time_elapsed    | 1861     |
# |    total_timesteps | 341850   |
# | train/             |          |
# |    actor_loss      | 61.4     |
# |    critic_loss     | 0.412    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341748   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.2     |
# |    ep_rew_mean     | -36.4    |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 183      |
# |    time_elapsed    | 1862     |
# |    total_timesteps | 341890   |
# | train/             |          |
# |    actor_loss      | 60.8     |
# |    critic_loss     | 0.101    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341788   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.1     |
# |    ep_rew_mean     | -37.1    |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 183      |
# |    time_elapsed    | 1862     |
# |    total_timesteps | 341930   |
# | train/             |          |
# |    actor_loss      | 58.8     |
# |    critic_loss     | 0.148    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341828   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.1     |
# |    ep_rew_mean     | -37.8    |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 183      |
# |    time_elapsed    | 1862     |
# |    total_timesteps | 341970   |
# | train/             |          |
# |    actor_loss      | 59.2     |
# |    critic_loss     | 0.387    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341868   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -38.5    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 183      |
# |    time_elapsed    | 1862     |
# |    total_timesteps | 342010   |
# | train/             |          |
# |    actor_loss      | 57.7     |
# |    critic_loss     | 0.147    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341908   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -39      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 183      |
# |    time_elapsed    | 1862     |
# |    total_timesteps | 342050   |
# | train/             |          |
# |    actor_loss      | 56.6     |
# |    critic_loss     | 0.206    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341948   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -39.4    |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 183      |
# |    time_elapsed    | 1863     |
# |    total_timesteps | 342090   |
# | train/             |          |
# |    actor_loss      | 55       |
# |    critic_loss     | 0.122    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 341988   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -39.8    |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 183      |
# |    time_elapsed    | 1863     |
# |    total_timesteps | 342130   |
# | train/             |          |
# |    actor_loss      | 55.3     |
# |    critic_loss     | 0.237    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342028   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -40.1    |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 183      |
# |    time_elapsed    | 1863     |
# |    total_timesteps | 342170   |
# | train/             |          |
# |    actor_loss      | 53.7     |
# |    critic_loss     | 0.262    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342068   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -40.5    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 183      |
# |    time_elapsed    | 1863     |
# |    total_timesteps | 342210   |
# | train/             |          |
# |    actor_loss      | 52.4     |
# |    critic_loss     | 0.0953   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342108   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -40.9    |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 183      |
# |    time_elapsed    | 1864     |
# |    total_timesteps | 342250   |
# | train/             |          |
# |    actor_loss      | 50.7     |
# |    critic_loss     | 0.177    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342148   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -41.2    |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 183      |
# |    time_elapsed    | 1864     |
# |    total_timesteps | 342290   |
# | train/             |          |
# |    actor_loss      | 51.4     |
# |    critic_loss     | 0.185    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342188   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -41.6    |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 183      |
# |    time_elapsed    | 1864     |
# |    total_timesteps | 342330   |
# | train/             |          |
# |    actor_loss      | 49.4     |
# |    critic_loss     | 0.266    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342228   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -41.8    |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 183      |
# |    time_elapsed    | 1864     |
# |    total_timesteps | 342370   |
# | train/             |          |
# |    actor_loss      | 48       |
# |    critic_loss     | 0.293    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342268   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -42      |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 183      |
# |    time_elapsed    | 1864     |
# |    total_timesteps | 342410   |
# | train/             |          |
# |    actor_loss      | 48.6     |
# |    critic_loss     | 0.138    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342308   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -42.4    |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 183      |
# |    time_elapsed    | 1865     |
# |    total_timesteps | 342450   |
# | train/             |          |
# |    actor_loss      | 46.5     |
# |    critic_loss     | 0.119    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342348   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -42.7    |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 183      |
# |    time_elapsed    | 1865     |
# |    total_timesteps | 342490   |
# | train/             |          |
# |    actor_loss      | 46       |
# |    critic_loss     | 0.128    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342388   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -43.1    |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 183      |
# |    time_elapsed    | 1865     |
# |    total_timesteps | 342530   |
# | train/             |          |
# |    actor_loss      | 44.7     |
# |    critic_loss     | 0.124    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342428   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -43.5    |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 183      |
# |    time_elapsed    | 1865     |
# |    total_timesteps | 342570   |
# | train/             |          |
# |    actor_loss      | 43.8     |
# |    critic_loss     | 0.144    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342468   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -43.8    |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 183      |
# |    time_elapsed    | 1865     |
# |    total_timesteps | 342610   |
# | train/             |          |
# |    actor_loss      | 42.4     |
# |    critic_loss     | 0.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342508   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -44      |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 183      |
# |    time_elapsed    | 1866     |
# |    total_timesteps | 342650   |
# | train/             |          |
# |    actor_loss      | 42.1     |
# |    critic_loss     | 0.103    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342548   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -44      |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 183      |
# |    time_elapsed    | 1866     |
# |    total_timesteps | 342690   |
# | train/             |          |
# |    actor_loss      | 41.1     |
# |    critic_loss     | 0.322    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342588   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -44      |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 183      |
# |    time_elapsed    | 1866     |
# |    total_timesteps | 342730   |
# | train/             |          |
# |    actor_loss      | 39.5     |
# |    critic_loss     | 0.255    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 342628   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -44      |
# ...
# |    actor_loss      | 5.5      |
# |    critic_loss     | 0.0149   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498276   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12212    |
# |    fps             | 183      |
# |    time_elapsed    | 2717     |
# |    total_timesteps | 498431   |
# | train/             |          |
# |    actor_loss      | 5.48     |
# |    critic_loss     | 0.0136   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498328   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12216    |
# |    fps             | 183      |
# |    time_elapsed    | 2717     |
# |    total_timesteps | 498483   |
# | train/             |          |
# |    actor_loss      | 5.41     |
# |    critic_loss     | 0.00457  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498380   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12220    |
# |    fps             | 183      |
# |    time_elapsed    | 2717     |
# |    total_timesteps | 498535   |
# | train/             |          |
# |    actor_loss      | 5.49     |
# |    critic_loss     | 0.00476  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498432   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12224    |
# |    fps             | 183      |
# |    time_elapsed    | 2718     |
# |    total_timesteps | 498587   |
# | train/             |          |
# |    actor_loss      | 5.65     |
# |    critic_loss     | 0.0887   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498484   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12228    |
# |    fps             | 183      |
# |    time_elapsed    | 2718     |
# |    total_timesteps | 498639   |
# | train/             |          |
# |    actor_loss      | 5.56     |
# |    critic_loss     | 0.00717  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498536   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12232    |
# |    fps             | 183      |
# |    time_elapsed    | 2718     |
# |    total_timesteps | 498691   |
# | train/             |          |
# |    actor_loss      | 5.69     |
# |    critic_loss     | 0.00504  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498588   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12236    |
# |    fps             | 183      |
# |    time_elapsed    | 2719     |
# |    total_timesteps | 498743   |
# | train/             |          |
# |    actor_loss      | 5.86     |
# |    critic_loss     | 0.0102   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498640   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12240    |
# |    fps             | 183      |
# |    time_elapsed    | 2719     |
# |    total_timesteps | 498795   |
# | train/             |          |
# |    actor_loss      | 5.77     |
# |    critic_loss     | 0.0043   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498692   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12244    |
# |    fps             | 183      |
# |    time_elapsed    | 2719     |
# |    total_timesteps | 498847   |
# | train/             |          |
# |    actor_loss      | 5.59     |
# |    critic_loss     | 0.00979  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12248    |
# |    fps             | 183      |
# |    time_elapsed    | 2720     |
# |    total_timesteps | 498899   |
# | train/             |          |
# |    actor_loss      | 5.8      |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498796   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12252    |
# |    fps             | 183      |
# |    time_elapsed    | 2720     |
# |    total_timesteps | 498951   |
# | train/             |          |
# |    actor_loss      | 5.86     |
# |    critic_loss     | 0.004    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12256    |
# |    fps             | 183      |
# |    time_elapsed    | 2720     |
# |    total_timesteps | 499003   |
# | train/             |          |
# |    actor_loss      | 5.62     |
# |    critic_loss     | 0.0427   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498900   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12260    |
# |    fps             | 183      |
# |    time_elapsed    | 2720     |
# |    total_timesteps | 499055   |
# | train/             |          |
# |    actor_loss      | 5.57     |
# |    critic_loss     | 0.144    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498952   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12264    |
# |    fps             | 183      |
# |    time_elapsed    | 2721     |
# |    total_timesteps | 499107   |
# | train/             |          |
# |    actor_loss      | 5.65     |
# |    critic_loss     | 0.0936   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499004   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12268    |
# |    fps             | 183      |
# |    time_elapsed    | 2721     |
# |    total_timesteps | 499159   |
# | train/             |          |
# |    actor_loss      | 5.69     |
# |    critic_loss     | 0.00929  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12272    |
# |    fps             | 183      |
# |    time_elapsed    | 2721     |
# |    total_timesteps | 499211   |
# | train/             |          |
# |    actor_loss      | 5.74     |
# |    critic_loss     | 0.00522  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499108   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11      |
# | time/              |          |
# |    episodes        | 12276    |
# |    fps             | 183      |
# |    time_elapsed    | 2721     |
# |    total_timesteps | 499263   |
# | train/             |          |
# |    actor_loss      | 5.87     |
# |    critic_loss     | 0.108    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499160   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.1    |
# | time/              |          |
# |    episodes        | 12280    |
# |    fps             | 183      |
# |    time_elapsed    | 2722     |
# |    total_timesteps | 499315   |
# | train/             |          |
# |    actor_loss      | 5.59     |
# |    critic_loss     | 0.00314  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499212   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12284    |
# |    fps             | 183      |
# |    time_elapsed    | 2722     |
# |    total_timesteps | 499365   |
# | train/             |          |
# |    actor_loss      | 5.73     |
# |    critic_loss     | 0.0171   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499264   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12288    |
# |    fps             | 183      |
# |    time_elapsed    | 2722     |
# |    total_timesteps | 499417   |
# | train/             |          |
# |    actor_loss      | 5.82     |
# |    critic_loss     | 0.148    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499316   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12292    |
# |    fps             | 183      |
# |    time_elapsed    | 2723     |
# |    total_timesteps | 499469   |
# | train/             |          |
# |    actor_loss      | 5.64     |
# |    critic_loss     | 0.0197   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499368   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12296    |
# |    fps             | 183      |
# |    time_elapsed    | 2723     |
# |    total_timesteps | 499521   |
# | train/             |          |
# |    actor_loss      | 5.83     |
# |    critic_loss     | 0.00948  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499420   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12300    |
# |    fps             | 183      |
# |    time_elapsed    | 2723     |
# |    total_timesteps | 499573   |
# | train/             |          |
# |    actor_loss      | 5.79     |
# |    critic_loss     | 0.0827   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12304    |
# |    fps             | 183      |
# |    time_elapsed    | 2723     |
# |    total_timesteps | 499625   |
# | train/             |          |
# |    actor_loss      | 5.59     |
# |    critic_loss     | 0.00539  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499524   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12308    |
# |    fps             | 183      |
# |    time_elapsed    | 2724     |
# |    total_timesteps | 499677   |
# | train/             |          |
# |    actor_loss      | 5.82     |
# |    critic_loss     | 0.00457  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499576   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12312    |
# |    fps             | 183      |
# |    time_elapsed    | 2724     |
# |    total_timesteps | 499729   |
# | train/             |          |
# |    actor_loss      | 5.62     |
# |    critic_loss     | 0.00415  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499628   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12316    |
# |    fps             | 183      |
# |    time_elapsed    | 2724     |
# |    total_timesteps | 499781   |
# | train/             |          |
# |    actor_loss      | 5.72     |
# |    critic_loss     | 0.00556  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499680   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12320    |
# |    fps             | 183      |
# |    time_elapsed    | 2724     |
# |    total_timesteps | 499833   |
# | train/             |          |
# |    actor_loss      | 5.87     |
# |    critic_loss     | 0.00677  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499732   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.3    |
# | time/              |          |
# |    episodes        | 12324    |
# |    fps             | 183      |
# |    time_elapsed    | 2725     |
# |    total_timesteps | 499885   |
# | train/             |          |
# |    actor_loss      | 5.61     |
# |    critic_loss     | 0.00377  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.4    |
# | time/              |          |
# |    episodes        | 12328    |
# |    fps             | 183      |
# |    time_elapsed    | 2725     |
# |    total_timesteps | 499937   |
# | train/             |          |
# |    actor_loss      | 5.57     |
# |    critic_loss     | 0.00537  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499836   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13       |
# |    ep_rew_mean     | -11.4    |
# | time/              |          |
# |    episodes        | 12332    |
# |    fps             | 183      |
# |    time_elapsed    | 2725     |
# |    total_timesteps | 499989   |
# | train/             |          |
# |    actor_loss      | 5.63     |
# |    critic_loss     | 0.0143   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499888   |
# ---------------------------------

# %%
# Test the trained agent
obs = env.reset()
OBS = np.zeros((14,3))
n_steps = 1000
for step in range(n_steps):
    action, _ = model.predict(obs, deterministic=True)
    print("Step {}".format(step + 1))
    print("Action: ", action)
    obs, reward, done, info = env.step(action)
    print('obs=', obs, 'reward=', reward, 'done=', done)
    # env.render(mode='console')
    OBS[step+1] = obs
    if done:
        # Note that the VecEnv resets automatically
        # when a done signal is encountered
        print("Goal reached!", "reward=", reward)
        break
# Out:
# Step 1
# Action:  [[0.9999958 1.        1.       ]]
# obs= [[0.9999958 1.        1.       ]] reward= [-1.] done= [False]
# Step 2
# Action:  [[ 0.97656536  1.         -0.04836106]]
# obs= [[1.9765612  2.         0.95163894]] reward= [-1.] done= [False]
# Step 3
# Action:  [[ 0.99939346  1.         -0.04262352]]
# obs= [[2.9759545 3.        0.9090154]] reward= [-1.] done= [False]
# Step 4
# Action:  [[0.35319114 1.         0.29385602]]
# obs= [[3.3291457 4.        1.2028714]] reward= [-1.] done= [False]
# Step 5
# Action:  [[0.38485265 1.         0.87581825]]
# obs= [[3.7139983 5.        2.0786896]] reward= [-1.] done= [False]
# Step 6
# Action:  [[0.81266344 1.         0.83166504]]
# obs= [[4.526662  6.        2.9103546]] reward= [-1.] done= [False]
# Step 7
# Action:  [[0.987561   1.         0.99249506]]
# obs= [[5.514223  7.        3.9028497]] reward= [-1.] done= [False]
# Step 8
# Action:  [[0.9864454 1.        1.       ]]
# obs= [[6.5006685 8.        4.9028497]] reward= [-1.] done= [False]
# Step 9
# Action:  [[0.9694021  0.58984697 1.        ]]
# obs= [[7.470071  8.589847  5.9028497]] reward= [-1.] done= [False]
# Step 10
# Action:  [[0.99999964 0.15270674 1.        ]]
# obs= [[8.470071  8.742554  6.9028497]] reward= [-1.] done= [False]
# Step 11
# Action:  [[ 1.         -0.21513587  1.        ]]
# obs= [[9.        8.527418  7.9028497]] reward= [-1.] done= [False]
# Step 12
# Action:  [[1.        0.7225034 1.       ]]
# obs= [[9.       9.       8.902849]] reward= [-1.] done= [False]
# Step 13
# Action:  [[1.         0.99102163 1.        ]]
# obs= [[0. 0. 0.]] reward= [1.] done= [ True]
# Goal reached! reward= [1.]

# %%
# Save the model
model.save('3d_grid_obstacle_continuous10x10')

# %%
# Load the model
# model = SAC.load('3d_grid_obstacle_continuous10x10')

# %%
# Save the results
from scipy import io
io.savemat('3d_grid_obstacle.mat',{'OBS':OBS})
