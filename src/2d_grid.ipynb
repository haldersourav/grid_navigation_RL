# %% [markdown]
# # Navigating a 2D grid by reinforcement learning (discrete action space)
#
# ## Salient features:
# 1) Custom Gym environment
# 2) Training a reinforcement learning agent using Stable-baselines
#
# ## Important links
# Stable-Baselines: https://github.com/hill-a/stable-baselines
#
# Documentation: https://stable-baselines.readthedocs.io/en/master/
#
# RL Baselines zoo: https://github.com/araffin/rl-baselines-zoo

# %%
from stable_baselines3.common.env_checker import check_env
import gym
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import DQN, A2C
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ## The gym interface
#
# The gym interface provides mainly three methods:
# - `reset()` called at the beginning of an episode, it returns an observation
# - `step(action)` called to take an action with the environment, it returns the next observation, the immediate reward, whether the episode is over and additional information
# - (Optional) `render(method='human')` which allow to visualize the agent in action. Note that graphical interface does not work on google colab, so we cannot use it directly (we have to rely on `method='rbg_array'` to retrieve an image of the scene
#
# Under the hood, it also contains two useful properties:
# - `observation_space` which one of the gym spaces (`Discrete`, `Box`, ...) and describe the type and shape of the observation
# - `action_space` which is also a gym space object that describes the action space, so the type of action that can be taken
#
# [Documentation on custom env](https://stable-baselines.readthedocs.io/en/master/guide/custom_env.html)
#
# [Documentation on custom env](https://stable-baselines.readthedocs.io/en/master/guide/custom_env.html)

# %% [markdown]
# ##  Gym environment

# %%
class ReachEndEnv(gym.Env):
    """
    Custom Environment that follows gym interface.
    This is a simple env where the agent must learn to reach the destination with obstacles in between. 
    """
    # Because of google colab, we cannot implement the GUI ('human' render mode)
    metadata = {'render.modes': ['console']}
    # Define constants for clearer code
    LEFT = 0
    RIGHT = 1
    UP = 2
    DOWN = 3

    def __init__(self, grid_size=4):
        super(ReachEndEnv, self).__init__()

        # Size of the 2D-grid
        self.grid_size = grid_size
        # Initialize the agent at the top left corner
        self.initial_pos = np.zeros((2,),dtype=np.float32) 
        self.agent_pos = np.zeros((2,),dtype=np.float32)
        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions, we have two: left and right
        n_actions = 4
        self.action_space = spaces.Discrete(n_actions)
        # The observation will be the coordinate of the agent
        # this can be described both by Discrete and Box space
        self.observation_space = spaces.Box(low=0, high=self.grid_size, shape=(2,), dtype=np.float32)
        # Check if goal is reached
        self.endcheck = False

    def reset(self):
        """
        Important: the observation must be a numpy array
        :return: (np.array) 
        """
        # Initialize the agent at the right of the grid
        self.agent_pos = np.zeros((2,),dtype=np.float32)#self.initial_pos
        # here we convert to float32 to make it more general (in case we want to use continuous actions)
        # return np.array([self.agent_pos]).astype(np.float32)
        return self.agent_pos

    def step(self, action):
        if action == self.LEFT:
            self.agent_pos[1] -= 1.0
        elif action == self.RIGHT:
            self.agent_pos[1] += 1.0
        elif action == self.UP:
            self.agent_pos[0] -= 1.0
        elif action == self.DOWN:
            self.agent_pos[0] += 1.0
        else:
            raise ValueError("Received invalid action={} which is not part of the action space".format(action))

        # Account for the boundaries of the grid
        self.agent_pos = np.clip(self.agent_pos, 0, self.grid_size-1)

        # Are we at the end?
        done = bool(self.agent_pos[0] == self.grid_size-1 and self.agent_pos[1]==self.grid_size-1)

        # Null reward everywhere except when reaching the goal (right corner)
        if self.agent_pos[0] == self.grid_size-1 and self.agent_pos[1]==self.grid_size-1: 
            reward = 1
        else:
            reward = -1

        # Optionally we can pass additional info, we are not using that for now
        info = {}
        self.endcheck = done

        return self.agent_pos, reward, done, info

    def render(self, mode='console'):
        if mode != 'console':
            raise NotImplementedError()
        # agent is represented as a cross, rest as a dot
        if self.endcheck:
            for i in range(self.grid_size-1):
                print ('.'*self.grid_size)
            print ('.'*(self.grid_size-1)+'x')
        else:
            for i in range(self.grid_size):                
                if i==int(self.agent_pos[0]):
                    print('.'*int(self.agent_pos[1]) + 'x' + '.'*(self.grid_size-int(self.agent_pos[1])-1))
                else:
                    print ('.'*self.grid_size)

    def close(self):
        pass

# %% [markdown]
# ### Validate the environment
#
# Stable Baselines provides a [helper](https://stable-baselines.readthedocs.io/en/master/common/env_checker.html) to check that your environment follows the Gym interface. It also optionally checks that the environment is compatible with Stable-Baselines (and emits warning if necessary).

# %%
# Instantiate the env
env = ReachEndEnv(grid_size=10)
# wrap it
env = make_vec_env(lambda: env, n_envs=1)

# %%
# Train the agent
model = DQN('MlpPolicy', env, train_freq= 4, tensorboard_log='./log_files/',verbose=1).learn(500000)
# Out:
# Using cuda device
# Logging to ./log_files/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 387      |
# |    ep_rew_mean      | -385     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 19026    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 546      |
# |    ep_rew_mean      | -544     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 14897    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 672      |
# |    ep_rew_mean      | -670     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 14025    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 634      |
# |    ep_rew_mean      | -632     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 13170    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 586      |
# |    ep_rew_mean      | -584     |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 13168    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 544      |
# |    ep_rew_mean      | -542     |
# |    exploration_rate | 0.752    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 13017    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 634      |
# |    ep_rew_mean      | -632     |
# |    exploration_rate | 0.662    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 12890    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 602      |
# |    ep_rew_mean      | -600     |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 12639    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19259    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 593      |
# |    ep_rew_mean      | -591     |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 12489    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 21333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 600      |
# |    ep_rew_mean      | -598     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 12411    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 24011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 588      |
# |    ep_rew_mean      | -586     |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 12232    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 25859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 590      |
# |    ep_rew_mean      | -588     |
# |    exploration_rate | 0.462    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 12054    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 28321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 570      |
# |    ep_rew_mean      | -568     |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11967    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 29635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | -559     |
# |    exploration_rate | 0.403    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 12019    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 31404    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 543      |
# |    ep_rew_mean      | -541     |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 12065    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 32561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | -536     |
# |    exploration_rate | 0.345    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 12019    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 34454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 541      |
# |    ep_rew_mean      | -539     |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11990    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 534      |
# |    ep_rew_mean      | -532     |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 12126    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 537      |
# |    ep_rew_mean      | -535     |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 12272    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 40784    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 544      |
# |    ep_rew_mean      | -542     |
# |    exploration_rate | 0.173    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 12353    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 43525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 532      |
# |    ep_rew_mean      | -530     |
# |    exploration_rate | 0.152    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 12304    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 44653    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | -525     |
# |    exploration_rate | 0.12     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 12343    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 46339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | -536     |
# |    exploration_rate | 0.0597   |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 12709    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 49492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 566      |
# |    ep_rew_mean      | -564     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5005     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 54338    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00251  |
# |    n_updates        | 1084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 557      |
# |    ep_rew_mean      | -555     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4203     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 55714    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 1428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 614      |
# |    ep_rew_mean      | -612     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2566     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 62966    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000994 |
# |    n_updates        | 3241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 601      |
# |    ep_rew_mean      | -599     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2388     |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 64506    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000498 |
# |    n_updates        | 3626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 582      |
# |    ep_rew_mean      | -580     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2218     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 66255    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000451 |
# |    n_updates        | 4063     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 574      |
# |    ep_rew_mean      | -572     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2120     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 67576    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000324 |
# |    n_updates        | 4393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 567      |
# |    ep_rew_mean      | -565     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2065     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 68427    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000317 |
# |    n_updates        | 4606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 558      |
# |    ep_rew_mean      | -556     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2039     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 68843    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000961 |
# |    n_updates        | 4710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 516      |
# |    ep_rew_mean      | -514     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2006     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 69365    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000532 |
# |    n_updates        | 4841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 509      |
# |    ep_rew_mean      | -507     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1961     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 70152    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 5037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 503      |
# |    ep_rew_mean      | -501     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1884     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 71587    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000479 |
# |    n_updates        | 5396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 476      |
# |    ep_rew_mean      | -474     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1881     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 71659    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000457 |
# |    n_updates        | 5414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | -459     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1868     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 71963    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000387 |
# |    n_updates        | 5490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | -435     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1864     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 72051    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000593 |
# |    n_updates        | 5512     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 425      |
# |    ep_rew_mean      | -423     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1861     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 72123    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00072  |
# |    n_updates        | 5530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 408      |
# |    ep_rew_mean      | -406     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1858     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 72198    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000494 |
# |    n_updates        | 5549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 397      |
# |    ep_rew_mean      | -395     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1854     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 72278    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000663 |
# |    n_updates        | 5569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 379      |
# |    ep_rew_mean      | -377     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1850     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 72350    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000474 |
# |    n_updates        | 5587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 358      |
# |    ep_rew_mean      | -356     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1838     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 72565    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000592 |
# |    n_updates        | 5641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 342      |
# |    ep_rew_mean      | -340     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1832     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 72642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000448 |
# |    n_updates        | 5660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 319      |
# |    ep_rew_mean      | -317     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1831     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 72722    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0002   |
# |    n_updates        | 5680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | -291     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1825     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 72858    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00053  |
# |    n_updates        | 5714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 283      |
# |    ep_rew_mean      | -281     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1818     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 72992    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000458 |
# |    n_updates        | 5747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 269      |
# |    ep_rew_mean      | -267     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1810     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73197    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000811 |
# |    n_updates        | 5799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 238      |
# |    ep_rew_mean      | -236     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1805     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73297    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000467 |
# |    n_updates        | 5824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1799     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73416    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000507 |
# |    n_updates        | 5853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1795     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 73491    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000463 |
# |    n_updates        | 5872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -104     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1792     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73572    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000356 |
# |    n_updates        | 5892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -90.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1785     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73738    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000493 |
# |    n_updates        | 5934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76       |
# |    ep_rew_mean      | -74      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1781     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73855    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000405 |
# |    n_updates        | 5963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.2     |
# |    ep_rew_mean      | -62.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1774     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 73998    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000156 |
# |    n_updates        | 5999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 57.5     |
# |    ep_rew_mean      | -55.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1767     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 74172    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000745 |
# |    n_updates        | 6042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 54       |
# |    ep_rew_mean      | -52      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1764     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74247    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000343 |
# |    n_updates        | 6061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 53.1     |
# |    ep_rew_mean      | -51.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1747     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74673    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000312 |
# |    n_updates        | 6168     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.2     |
# |    ep_rew_mean      | -44.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1743     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 74768    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000335 |
# |    n_updates        | 6191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.9     |
# |    ep_rew_mean      | -31.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1736     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 74976    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000433 |
# |    n_updates        | 6243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 33.9     |
# |    ep_rew_mean      | -31.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1733     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75051    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000539 |
# |    n_updates        | 6262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.8     |
# |    ep_rew_mean      | -29.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1729     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75138    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00036  |
# |    n_updates        | 6284     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 31.6     |
# |    ep_rew_mean      | -29.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1726     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75211    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00047  |
# |    n_updates        | 6302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 32.9     |
# |    ep_rew_mean      | -30.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1718     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 75410    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00175  |
# |    n_updates        | 6352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.7     |
# |    ep_rew_mean      | -33.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1708     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75769    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000426 |
# |    n_updates        | 6442     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 35.6     |
# |    ep_rew_mean      | -33.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1705     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75842    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000559 |
# |    n_updates        | 6460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.1     |
# |    ep_rew_mean      | -34.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1701     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 75962    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 6490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36       |
# |    ep_rew_mean      | -34      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1694     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 76169    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00065  |
# |    n_updates        | 6542     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37       |
# |    ep_rew_mean      | -35      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1687     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76337    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000378 |
# |    n_updates        | 6584     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | -34.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1685     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000445 |
# |    n_updates        | 6603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.9     |
# |    ep_rew_mean      | -34.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1680     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76545    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0734   |
# |    n_updates        | 6636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 37.4     |
# |    ep_rew_mean      | -35.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1673     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 76729    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000485 |
# |    n_updates        | 6682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.6     |
# |    ep_rew_mean      | -34.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1669     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 76854    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000275 |
# |    n_updates        | 6713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.3     |
# |    ep_rew_mean      | -34.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1666     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 76930    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00031  |
# |    n_updates        | 6732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 36.7     |
# |    ep_rew_mean      | -34.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1661     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 77087    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000551 |
# |    n_updates        | 6771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38       |
# |    ep_rew_mean      | -36      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1654     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 77290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000456 |
# |    n_updates        | 6822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.8     |
# |    ep_rew_mean      | -36.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1649     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 77453    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000735 |
# |    n_updates        | 6863     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 38.4     |
# |    ep_rew_mean      | -36.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1644     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 77577    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000787 |
# |    n_updates        | 6894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.2     |
# |    ep_rew_mean      | -38.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1636     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 77872    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0732   |
# |    n_updates        | 6967     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 39.5     |
# |    ep_rew_mean      | -37.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1633     |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 77949    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000484 |
# |    n_updates        | 6987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | -38.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1625     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 78221    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00023  |
# |    n_updates        | 7055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.6     |
# |    ep_rew_mean      | -40.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1615     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 78503    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000899 |
# |    n_updates        | 7125     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41       |
# |    ep_rew_mean      | -39      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1606     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 78772    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000165 |
# |    n_updates        | 7192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41       |
# |    ep_rew_mean      | -39      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1604     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 78864    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000234 |
# |    n_updates        | 7215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.5     |
# |    ep_rew_mean      | -38.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1599     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 79025    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000362 |
# |    n_updates        | 7256     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.5     |
# |    ep_rew_mean      | -39.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1593     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 79196    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00059  |
# |    n_updates        | 7298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.4     |
# |    ep_rew_mean      | -39.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1590     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 79273    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0013   |
# |    n_updates        | 7318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 42.6     |
# |    ep_rew_mean      | -40.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1584     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 79473    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000785 |
# |    n_updates        | 7368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.8     |
# |    ep_rew_mean      | -39.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1581     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 79591    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000836 |
# |    n_updates        | 7397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 40.8     |
# |    ep_rew_mean      | -38.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1574     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 79853    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000792 |
# |    n_updates        | 7463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.1     |
# |    ep_rew_mean      | -39.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1572     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 79950    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0724   |
# |    n_updates        | 7487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 41.3     |
# |    ep_rew_mean      | -39.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1571     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 80088    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0415   |
# |    n_updates        | 7521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.6     |
# |    ep_rew_mean      | -44.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1551     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 80829    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00236  |
# |    n_updates        | 7707     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.4     |
# |    ep_rew_mean      | -45.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1546     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 81072    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000538 |
# |    n_updates        | 7767     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.8     |
# |    ep_rew_mean      | -45.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1543     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 81188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.099    |
# |    n_updates        | 7796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.3     |
# |    ep_rew_mean      | -46.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1537     |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 81376    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 7843     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47.8     |
# |    ep_rew_mean      | -45.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1534     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 81507    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000773 |
# |    n_updates        | 7876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 48.6     |
# |    ep_rew_mean      | -46.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1528     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 81712    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.001    |
# |    n_updates        | 7927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -48      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# ...
# |    time_elapsed     | 671      |
# |    total_timesteps  | 497726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000131 |
# |    n_updates        | 111931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20824    |
# |    fps              | 741      |
# |    time_elapsed     | 671      |
# |    total_timesteps  | 497800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000301 |
# |    n_updates        | 111949   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20828    |
# |    fps              | 741      |
# |    time_elapsed     | 671      |
# |    total_timesteps  | 497872   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000352 |
# |    n_updates        | 111967   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20832    |
# |    fps              | 741      |
# |    time_elapsed     | 671      |
# |    total_timesteps  | 497948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.35e-05 |
# |    n_updates        | 111986   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20836    |
# |    fps              | 741      |
# |    time_elapsed     | 671      |
# |    total_timesteps  | 498020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00016  |
# |    n_updates        | 112004   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20840    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498102   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000227 |
# |    n_updates        | 112025   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20844    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498181   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000142 |
# |    n_updates        | 112045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20848    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498255   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000198 |
# |    n_updates        | 112063   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20852    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498329   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00146  |
# |    n_updates        | 112082   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20856    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000149 |
# |    n_updates        | 112100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20860    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498479   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.39e-05 |
# |    n_updates        | 112119   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20864    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498553   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 112138   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20868    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498631   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000395 |
# |    n_updates        | 112157   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20872    |
# |    fps              | 741      |
# |    time_elapsed     | 672      |
# |    total_timesteps  | 498703   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000467 |
# |    n_updates        | 112175   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20876    |
# |    fps              | 741      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 498778   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000288 |
# |    n_updates        | 112194   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20880    |
# |    fps              | 741      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 498853   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00011  |
# |    n_updates        | 112213   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20884    |
# |    fps              | 740      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 498927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000312 |
# |    n_updates        | 112231   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20888    |
# |    fps              | 741      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 498999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000871 |
# |    n_updates        | 112249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20892    |
# |    fps              | 741      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 499073   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000583 |
# |    n_updates        | 112268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20896    |
# |    fps              | 741      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 499154   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000368 |
# |    n_updates        | 112288   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20900    |
# |    fps              | 740      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 499230   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.44e-05 |
# |    n_updates        | 112307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20904    |
# |    fps              | 740      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 499302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000186 |
# |    n_updates        | 112325   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20908    |
# |    fps              | 740      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 499376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.5e-05  |
# |    n_updates        | 112343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20912    |
# |    fps              | 740      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499450   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000109 |
# |    n_updates        | 112362   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20916    |
# |    fps              | 740      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000209 |
# |    n_updates        | 112380   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | -16.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20920    |
# |    fps              | 740      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00012  |
# |    n_updates        | 112399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | -16.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20924    |
# |    fps              | 740      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499679   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.09e-05 |
# |    n_updates        | 112419   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20928    |
# |    fps              | 741      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499757   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000528 |
# |    n_updates        | 112439   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20932    |
# |    fps              | 741      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00029  |
# |    n_updates        | 112458   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20936    |
# |    fps              | 740      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499911   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 112477   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20940    |
# |    fps              | 740      |
# |    time_elapsed     | 674      |
# |    total_timesteps  | 499989   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000245 |
# |    n_updates        | 112497   |
# ----------------------------------

# %%
# Test the trained agent
obs = env.reset()

n_steps = 1000
for step in range(n_steps):
    action, _ = model.predict(obs, deterministic=True)
    print("Step {}".format(step + 1))
    print("Action: ", action)
    obs, reward, done, info = env.step(action)
    print('obs=', obs, 'reward=', reward, 'done=', done)
    env.render(mode='console')
    if done:
        # Note that the VecEnv resets automatically
        # when a done signal is encountered
        print("Goal reached!", "reward=", reward)
        break
# Out:
# Step 1
# Action:  [3]
# obs= [[1. 0.]] reward= [-1.] done= [False]
# ..........
# x.........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# Step 2
# Action:  [1]
# obs= [[1. 1.]] reward= [-1.] done= [False]
# ..........
# .x........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# Step 3
# Action:  [3]
# obs= [[2. 1.]] reward= [-1.] done= [False]
# ..........
# ..........
# .x........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# Step 4
# Action:  [1]
# obs= [[2. 2.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..x.......
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# Step 5
# Action:  [3]
# obs= [[3. 2.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..x.......
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# Step 6
# Action:  [3]
# obs= [[4. 2.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..x.......
# ..........
# ..........
# ..........
# ..........
# ..........
# Step 7
# Action:  [3]
# obs= [[5. 2.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..x.......
# ..........
# ..........
# ..........
# ..........
# Step 8
# Action:  [3]
# obs= [[6. 2.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..x.......
# ..........
# ..........
# ..........
# Step 9
# Action:  [3]
# obs= [[7. 2.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..x.......
# ..........
# ..........
# Step 10
# Action:  [3]
# obs= [[8. 2.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..x.......
# ..........
# Step 11
# Action:  [1]
# obs= [[8. 3.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ...x......
# ..........
# Step 12
# Action:  [1]
# obs= [[8. 4.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ....x.....
# ..........
# Step 13
# Action:  [1]
# obs= [[8. 5.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# .....x....
# ..........
# Step 14
# Action:  [1]
# obs= [[8. 6.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ......x...
# ..........
# Step 15
# Action:  [1]
# obs= [[8. 7.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# .......x..
# ..........
# Step 16
# Action:  [1]
# obs= [[8. 8.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ........x.
# ..........
# Step 17
# Action:  [1]
# obs= [[8. 9.]] reward= [-1.] done= [False]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# .........x
# ..........
# Step 18
# Action:  [3]
# obs= [[0. 0.]] reward= [1.] done= [ True]
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# .........x
# Goal reached! reward= [1.]

# %%
obs = env.reset()
print('obs=', obs, 'reward=', reward, 'done=', done)
env.render(mode='console')
# Out:
# obs= [[-394.  102.]] reward= [1.] done= [ True]
# ....
# ....
# ....
# ....

# %%
a = [3,4]
np.clip(a,0,3)
# Out:
# array([3, 3])
